# %%
from datetime import datetime
import os

ts = datetime.now().strftime("%Y%m%d_%H%M%S")

base_path = "/Workspace/Shubham_demo"
filename = f"xyz_{ts}.txt"
full_path = os.path.join(base_path, filename)

with open(full_path, "w") as f:
    f.write(f"File created at {ts}\n")

print("Created:", full_path)
print("Exists:", os.path.exists(full_path))
print("Dir contents:", os.listdir(base_path))
# Out:
# Created: /Workspace/Shubham_demo/xyz_20260320_061951.txt
# Exists: True
# Dir contents: ['Python_job.job', 'ReadMe.md', 'Test_File_With_Space_Rename_Testing_Chaos_Rename_Twice', 'Test_File_With_Space_Rename_Testing_renamed_once', 'Test_File_With_Space_Rename_Testing_renamed_twice', 'Untitled_1773984113424759.ipynb', 'xyz_20260320_054701.txt', 'xyz_20260320_061708.txt', 'xyz_20260320_061713.txt', 'xyz_20260320_061951.txt', 'fole name with space']
